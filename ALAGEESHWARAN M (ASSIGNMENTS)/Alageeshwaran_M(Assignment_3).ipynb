# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.scatter(df.index,df['CreditScore'])
plt.show()

# %%
sns.scatterplot (x=df.index,y=df['CreditScore'],hue=df['Gender'])

# %%
df1=df.sample(frac=0.35)

# %%
plt.figure(figsize=(5,5))
plt.pie(df1['Gender'].value_counts(),startangle=90,autopct='%.3f',labels=['Male','Female'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7f6b26e5d0>,
# ...
#  [Text(-1.0928605779122968, -0.12512296849579824, 'Male'),
#   Text(1.09286058962715, 0.12512286617480578, 'Female')],
#  [Text(-0.5961057697703437, -0.06824889190679903, '53.629'),
#   Text(0.5961057761602636, 0.0682488360953486, '46.371')])

# %%
sns.barplot(x='NumOfProducts',y='Tenure',data=df)

# %%
sns.boxplot(x='NumOfProducts',y='CreditScore',data=df,palette='rainbow')

# %%
sns.pairplot(df, hue='NumOfProducts', size=2.5);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df['Age'].mode()
# Out:
# 0    37
# dtype: int64

# %%
df["Age"].mean()
# Out:
# 38.9218

# %%
df["Age"].median()
# Out:
# 37.0

# %%
df['Age'].quantile([.25, .5, .75])
# Out:
# 0.25    32.0
# 0.50    37.0
# 0.75    44.0
# Name: Age, dtype: float64

# %%
df['Age'].max() - df['Age'].min()
# Out:
# 74

# %%
round(df['Age'].std(),2)
# Out:
# 10.49

# %%
round(df.describe(),2)
# Out:
#        RowNumber   CustomerId  CreditScore       Age    Tenure    Balance  \
# count   10000.00     10000.00     10000.00  10000.00  10000.00   10000.00
# mean     5000.50  15690940.57       650.53     38.92      5.01   76485.89
# std      2886.90     71936.19        96.65     10.49      2.89   62397.41
# min         1.00  15565701.00       350.00     18.00      0.00       0.00
# 25%      2500.75  15628528.25       584.00     32.00      3.00       0.00
# 50%      5000.50  15690738.00       652.00     37.00      5.00   97198.54
# 75%      7500.25  15753233.75       718.00     44.00      7.00  127644.24
# max     10000.00  15815690.00       850.00     92.00     10.00  250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10000.00   10000.00        10000.00         10000.00  10000.0
# mean            1.53       0.71            0.52        100090.24      0.2
# std             0.58       0.46            0.50         57510.49      0.4
# ...

# %%
df['Age'].groupby(df['Gender']).describe()
# Out:
#          count       mean        std   min   25%   50%   75%   max
# Gender
# Female  4543.0  39.238389  10.588588  18.0  32.0  38.0  45.0  85.0
# Male    5457.0  38.658237  10.396780  18.0  32.0  37.0  43.0  92.0

# %%
sns.boxplot(df.Balance);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Balance'] = df['Balance'].replace(0.00,df['Balance'].mean())

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
sns.boxplot(df.CreditScore);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(df['CreditScore'].quantile(0.50))
# Out:
# 652.0

# %%
print(df['CreditScore'].quantile(0.95))
# Out:
# 812.0

# %%
df['CreditScore'] = np.where(df['CreditScore'] > 812, 652, df['CreditScore'])

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    641.183700     38.921800      5.012800
# std     2886.89568  7.193619e+04     86.421079     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    704.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    812.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean   104150.835443       1.530200      0.70550        0.515100
# std     31809.130134       0.581654      0.45584        0.499797
# ...

# %%
cols = df.columns
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
list(set(cols) - set(num_cols))
# Out:
# ['Geography', 'Surname', 'Gender']

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='Exited',data=df)
plt.xlabel(" 0 - Still With bank :: 1- Exited From Bank")
plt.ylabel(" Count ")
plt.title(" Visual ")
plt.show()

# %%
x = df.drop('Exited',axis=1)
y = df['Exited']

# %%
x.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          652     Spain  Female   43
#
#    Tenure        Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2   76485.889288              1          1               1
# 1       1   83807.860000              1          0               1
# 2       8  159660.800000              3          1               0
# 3       1   76485.889288              2          0               0
# 4       2  125510.820000              1          1               1
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train
# Out:
#       RowNumber  CustomerId           Surname  CreditScore Geography  Gender  \
# 7389       7390    15676909            Mishin          667     Spain  Female
# 9275       9276    15749265           Carslaw          427   Germany    Male
# 2995       2996    15582492             Moore          535    France  Female
# 5316       5317    15780386             Ferri          654     Spain    Male
# 356         357    15611759           Simmons          652     Spain  Female
# ...         ...         ...               ...          ...       ...     ...
# 9225       9226    15584928  Ugochukwutubelum          594   Germany  Female
# 4859       4860    15647111             White          794     Spain  Female
# 3264       3265    15574372            Hoolan          738    France    Male
# 9845       9846    15664035           Parsons          590     Spain  Female
# 2732       2733    15592816          Udokamma          623   Germany  Female
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print('X train shape : {}, Y train shape {}'.format(x_train.shape, y_train.shape))
# Out:
# X train shape : (8000, 13), Y train shape (8000,)

# %%
print('X test shape : {}, Y test shape {}'.format(x_test.shape, y_test.shape))
# Out:
# X test shape : (2000, 13), Y test shape (2000,)

# %%
x_train
# Out:
#       RowNumber  CustomerId           Surname  CreditScore Geography  Gender  \
# 7389       7390    15676909            Mishin          667     Spain  Female
# 9275       9276    15749265           Carslaw          427   Germany    Male
# 2995       2996    15582492             Moore          535    France  Female
# 5316       5317    15780386             Ferri          654     Spain    Male
# 356         357    15611759           Simmons          652     Spain  Female
# ...         ...         ...               ...          ...       ...     ...
# 9225       9226    15584928  Ugochukwutubelum          594   Germany  Female
# 4859       4860    15647111             White          794     Spain  Female
# 3264       3265    15574372            Hoolan          738    France    Male
# 9845       9846    15664035           Parsons          590     Spain  Female
# 2732       2733    15592816          Udokamma          623   Germany  Female
#
# ...
